# %% [markdown]
# <a href="https://colab.research.google.com/github/princessivy/Analyzing_CSGO_SkinPrices/blob/main/Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installs and Imports

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Let's Scrape

# %%
result = requests.get("https://skinport.com/de/market")

# %%
result.status_code #page is accessable
# Out:
# 200

# %%
result.headers #extra information
# Out:
# {'Date': 'Thu, 17 Mar 2022 10:38:48 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '6ed519e20d166b56-AMS', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'Content-Security-Policy': "frame-ancestors 'none'; upgrade-insecure-requests; report-uri https://skinport.report-uri.com/r/d/csp/enforce", 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Feature-Policy': "geolocation 'none'; microphone 'none'; payment 'none'; sync-xhr 'none'", 'Referrer-Policy': 'no-referrer-when-downgrade', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny', 'X-Powered-By': 'Express', 'X-XSS-Protection': '1; mode=block', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'Content-Encoding': 'gzip'}

# %%
src = result.content #look at the source of the page

# %%
src
# Out:
# b'<!DOCTYPE html><html class="isNotMobile" lang="de" data-react-helmet="lang"><head> <meta charset="UTF-8"> <meta name="viewport" content="width=device-width,user-scalable=no,initial-scale=1,maximum-scale=1,minimum-scale=1"> <meta http-equiv="X-UA-Compatible" content="ie=edge"> <title>CS:GO Marktplatz - CS:GO Skins und Gegenst\xc3\xa4nde kaufen - Skinport</title> <link href="https://fonts.googleapis.com/css?family=Montserrat:400,600,700&amp;display=swap" rel="stylesheet"> <link rel="apple-touch-icon" sizes="180x180" href="/static/apple-touch-icon.png"> <link rel="icon" type="image/png" sizes="32x32" href="/static/favicon-32x32.png"> <link rel="icon" type="image/png" sizes="16x16" href="/static/favicon-16x16.png"> <link rel="manifest" href="/static/site.webmanifest"> <link rel="mask-icon" href="/static/safari-pinned-tab.svg" color="#4db5da"> <link rel="shortcut icon" href="/static/favicon.ico"> <meta name="msapplication-TileColor" content="#232728"> <meta name="msapplication-config" c
# ...

# %%
soup = BeautifulSoup(src, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
scripts = soup.find_all("a") #sind 50 stück

# %%
# aus https://stackoverflow.com/questions/69398197/how-do-i-fetch-all-the-price-from-this-url-using-beautiful-soup
# zeigt preise

u = 'https://skinport.com/market?cat=Knife&item=Doppler&type=M9+Bayonet&sort=price&order=asc'
r = requests.get(u)
c = r.content.decode('utf-8')
soup = BeautifulSoup(c, "html.parser")
price = soup.find_all('div', {"class": "ItemPreview-priceValue"})
print(price)
# Out:
# [<div class="Tooltip-link"></div>, <div class="Tooltip-link"><img alt="PGL (Holo) | Stockholm 2021" class="ItemPreview-sticker" loading="lazy" src="https://steamcdn-a.akamaihd.net/apps/730/icons/econ/stickers/stockh2021/pgl_holo.279e05916f12ac34c47edef4ee9f4f1bcb1f2590.png"/></div>, <div class="Tooltip-link"><img alt="FURIA (Holo) | Stockholm 2021" class="ItemPreview-sticker" loading="lazy" src="https://steamcdn-a.akamaihd.net/apps/730/icons/econ/stickers/stockh2021/furi_holo.2f141d420fa296622dada841d32240798e13fe6a.png"/></div>, <div class="Tooltip-link"><img alt="Team Liquid (Holo) | Stockholm 2021" class="ItemPreview-sticker" loading="lazy" src="https://steamcdn-a.akamaihd.net/apps/730/icons/econ/stickers/stockh2021/liq_holo.593b5b13324c77b28b49f71342140105c28ab60a.png"/></div>, <div class="Tooltip-link"><img alt="Team Liquid (Foil) | Stockholm 2021" class="ItemPreview-sticker" loading="lazy" src="https://steamcdn-a.akamaihd.net/apps/730/icons/econ/stickers/stockh2021/liq_foil.586
# ...

# %%
# Out:
# 50

# %% [markdown]
# Scrapy

# %%
# !pip install scrapy --quiet

# %%
fetch('https://stackoverflow.com/questions/54994218/how-to-scrape-from-xhr-in-chrome-python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-b5644b640000> in <module>()
# ----> 1 fetch('https://stackoverflow.com/questions/54994218/how-to-scrape-from-xhr-in-chrome-python')
#
# NameError: name 'fetch' is not defined
